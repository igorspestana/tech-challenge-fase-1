# %% [markdown]
# # Mudamos para o google colab pois ele ja tem uma gpu gratuita (precisa de GPU para rodar o código)
#
# Porém, ainda teremos esse código aqui, por meio de estudo e revisitar quando necessário
